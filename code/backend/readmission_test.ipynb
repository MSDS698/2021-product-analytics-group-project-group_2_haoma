# %%
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd

# %%
df = pd.read_excel('readmission_1.xlsx')
df_sample = df.sample(frac=0.7)

# %%
df_sample
# Out:
#           Date  Patient ID Gender    Age        Service
# 60  2025-03-02        61.0      F   59.0           CHHA
# 344 2025-12-11       345.0      M   98.0        Nursing
# 127 2025-05-08       128.0      F   68.0             ST
# 180 2025-06-30       181.0      F   99.0             OT
# 338 2025-12-05       339.0      M  110.0  Social Worker
# ..         ...         ...    ...    ...            ...
# 354 2025-12-21       355.0      F   64.0           CHHA
# 363 2025-12-30       364.0      M   91.0             PT
# 319 2025-11-16       320.0      M   98.0           CHHA
# 20  2025-01-21        21.0      M   66.0             ST
# 223 2025-08-12       224.0      M   66.0             OT
#
# [256 rows x 5 columns]

# %%
fig = px.histogram(df_sample, x="Date", color="Gender", color_discrete_sequence=['#DB4437', '#4285F4'], opacity=0.75)
fig.update_layout(
    title_text='Number of Readmission', # title of plot
    xaxis_title_text='Date', # xaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1 # gap between bars of the same location coordinates
)
fig.show()
# Out:
# <div>                            <div id="47bb59bb-1f6f-4335-96a2-4147abbde255" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47bb59bb-1f6f-4335-96a2-4147abbde255")) {                    Plotly.newPlot(                        "47bb59bb-1f6f-4335-96a2-4147abbde255",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Gender=F<br>Date=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "F", "marker": {"color": "#DB4437", "opacity": 0.75}, "name": "F", "offsetgroup": "F", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["2025-03-02T00:00:00", "2025-05-08T00:00:00", "2025-06-30T00:00:00", "2025-01-02T00:00:00", "2025-06-12T00:00:00", "2025-08-30T00:00:00", "2025-09-05T00:00:00", "2025-05-03T00:00:00",
# ...

# %%
fig = px.histogram(df_sample, y="Service")
fig.show()
# Out:
# <div>                            <div id="a05e8ec2-8645-408d-8c31-658dca3496d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a05e8ec2-8645-408d-8c31-658dca3496d5")) {                    Plotly.newPlot(                        "a05e8ec2-8645-408d-8c31-658dca3496d5",                        [{"alignmentgroup": "True", "bingroup": "y", "hovertemplate": "count=%{x}<br>Service=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "type": "histogram", "xaxis": "x", "y": ["CHHA", "Nursing", "ST", "OT", "Social Worker", "CHHA", "OT", "CHHA", "Social Worker", "ST", "PT", "Nursing", "CHHA", "PT", "OT", "Nursing", "OT", "PT", "OT", "PT", "OT", "Nursing", "Nursing", "Soc
# ...
